# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasst07/Challenge-Telecom-X-an-lise-de-evas-o-de-clientes-/blob/main/TelecomX_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##📚 Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ##📌 Extracão

# %%
url= 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json'

# %%
df = pd.read_json(url)
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
#normalizando os dados Json
dados = pd.json_normalize(df.to_dict('records'))
display(dados)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %% [markdown]
# ##🔧 Transformação

# %% [markdown]
# ###Dicionário de dados
# - customerID: número de identificação único de cada cliente
# - Churn: se o cliente deixou ou não a empresa
# - gender: gênero (masculino e feminino)
# - SeniorCitizen: informação sobre um cliente ter ou não idade igual ou maior que 65 anos
# - Partner: se o cliente possui ou não um parceiro ou parceira
# - Dependents: se o cliente possui ou não dependentes
# - tenure: meses de contrato do cliente
# - PhoneService: assinatura de serviço telefônico
# - MultipleLines: assisnatura de mais de uma linha de telefone
# - InternetService: assinatura de um provedor internet
# - OnlineSecurity: assinatura adicional de segurança online
# - OnlineBackup: assinatura adicional de backup online
# - DeviceProtection: assinatura adicional de proteção no dispositivo
# - TechSupport: assinatura adicional de suporte técnico, menos tempo de espera
# - StreamingTV: assinatura de TV a cabo
# - StreamingMovies: assinatura de streaming de filmes
# - Contract: tipo de contrato
# - PaperlessBilling: se o cliente prefere receber online a fatura
# - PaymentMethod: forma de pagamento
# - Charges.Monthly: total de todos os serviços do cliente por mês
# - Charges.Total: total gasto pelo cliente

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
dados.describe()
# Out:
#        customer.SeniorCitizen  customer.tenure  account.Charges.Monthly
# count             7267.000000      7267.000000              7267.000000
# mean                 0.162653        32.346498                64.720098
# std                  0.369074        24.571773                30.129572
# min                  0.000000         0.000000                18.250000
# 25%                  0.000000         9.000000                35.425000
# 50%                  0.000000        29.000000                70.300000
# 75%                  0.000000        55.000000                89.875000
# max                  1.000000        72.000000               118.750000

# %%
#mudando o tipo de dado na coluna 'Total'
dados['account.Charges.Total'] = dados['account.Charges.Total'].replace(' ', np.nan)
dados['account.Charges.Total'] = dados['account.Charges.Total'].astype(np.float64)

# %%
# contagem de valores nulos
dados.isnull().sum()
# Out:
# customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64

# %%
#contagem dos valores da coluna evasão
dados['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
#eliminando valores nulos na coluna Churn (224 pessoas)
dados = dados[dados['Churn'].isin(['Yes', 'No'])].copy()

# %%
dados['internet.InternetService'].value_counts() # valores do serviço de internet
# Out:
# internet.InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
dados.groupby('customer.SeniorCitizen')['Churn'].value_counts() #informação sobre um cliente ter ou não idade igual ou maior que 65 anos
# Out:
# customer.SeniorCitizen  Churn
# 0                       No       4508
#                         Yes      1393
# 1                       No        666
#                         Yes       476
# Name: count, dtype: int64

# %%
#criando uma coluna valor_diario
dados['account.Charges.Daily'] = dados['account.Charges.Monthly'] / 30

# %%
dados['account.Charges.Daily'].value_counts()
# Out:
# account.Charges.Daily
# 0.668333    61
# 0.661667    45
# 0.665000    44
# 0.663333    44
# 0.656667    43
#             ..
# 3.781667     1
# 3.916667     1
# 3.871667     1
# 2.085000     1
# 3.873333     1
# Name: count, Length: 1585, dtype: int64

# %%
#contagem de colunas dos serviços
colunas_servicos_adc = ['phone.PhoneService',
                        'phone.MultipleLines',
                        'internet.OnlineSecurity',
                        'internet.OnlineBackup',
                        'internet.DeviceProtection',
                        'internet.TechSupport',
                        'internet.StreamingTV',
                        'internet.StreamingMovies']

for coluna in colunas_servicos_adc:
    dados[coluna] = dados[coluna].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
#criando uma nova coluna para o dataset
dados['NumAddonServices'] = dados[['phone.PhoneService',
                                   'phone.MultipleLines',
                        'internet.OnlineSecurity',
                        'internet.OnlineBackup',
                        'internet.DeviceProtection',
                        'internet.TechSupport',
                        'internet.StreamingTV',
                        'internet.StreamingMovies']].sum(axis=1)

# %%
print("\nDistribuição da quantidade de serviços adicionais por cliente:")
print(dados['NumAddonServices'].value_counts())
# Out:
# Distribuição da quantidade de serviços adicionais por cliente:
# NumAddonServices
# 1    1701
# 2    1188
# 3     965
# 4     922
# 5     908
# 6     676
# 7     395
# 8     208
# 0      80
# Name: count, dtype: int64

# %% [markdown]
# ##📊 Carga e análise

# %%
def cost_group(valor):
  if valor <= 1.5:
      return 'Custo diário (R$ 0 - 1.5)'
  elif valor > 1.5 and valor <= 2.5:
      return 'Custo diário (R$ 1.51 - 2.5)'
  else:
      return 'Custo diário (2.51 - 3+)'

dados['account.Charges.Daily2'] = dados['account.Charges.Daily'].apply(cost_group)

fig, ax = plt.subplots(figsize=(8,4))
ax = sns.countplot(data=dados, y='account.Charges.Daily2', hue='Churn')

plt.title("Evasões por custo diário\n", fontsize=16)
plt.ylabel('')
plt.xlabel('Quantidade de Clientes\n', fontsize=12)
for i in ax.containers:
    ax.bar_label(
        i,
        fmt='%.1f',
        padding=1,
        fontsize=10,
        color='black'
)
plt.grid(linestyle=':')
plt.legend(title='Evasão', labels=['Não', 'Sim'])
sns.despine()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.countplot(data=dados, x='account.Contract', hue='Churn')
plt.xticks([0, 1, 2], ['Contrato anual', 'Contrato mensal', 'Contrato bi-anual'])
plt.title("Evasões por Tipo de Contrato\n", fontsize=16)
plt.xlabel('')
plt.ylabel('Quantidade de Clientes\n', fontsize=12)
for i in ax.containers:
    ax.bar_label(
        i,
        fmt='%.1f',    # Formato com 1 decimal
        padding=1,     # Espaçamento
        fontsize=10,
        color='black'
)
plt.grid(linestyle=':')
plt.legend(title='Evasão', labels=['Não', 'Sim'])
sns.despine()
plt.show()

# %%
g = sns.catplot(data=dados, x='account.Charges.Daily2', hue='Churn', col='account.Contract',
                kind='count', height=5, aspect=.8)

g.fig.suptitle('Evasões por Custo Diário e Tipo de Contrato', y=1.03, fontsize=16)
g.set_axis_labels("Custo Diário", "Quantidade de Clientes")
g.set_titles("Contrato: {col_name}")
g.set_xticklabels(rotation=45, ha='right')


for ax in g.axes.flat:
    for container in ax.containers:
        ax.bar_label(container, padding=3, fontsize=9, color='black')


plt.tight_layout() # Adjust layout
plt.show()

# %%
g = sns.catplot(data=dados, x='NumAddonServices', hue='Churn', col='account.Contract',
                kind='count', height=5, aspect=.8)

g.fig.suptitle('Evasões por Quantidade de Serviços e Tipo de Contrato', y=1.03, fontsize=16)
g.set_axis_labels("Quantidade de Serviços\n", "Quantidade de Clientes\n")
g.set_titles("Contrato: {col_name}")


for ax in g.axes.flat:
    for container in ax.containers:
        ax.bar_label(container, padding=3, fontsize=9, color='black')


plt.tight_layout() # Adjust layout
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax =sns.countplot(data=dados, x='customer.gender', hue='Churn')
plt.xticks([0, 1], ['Masculino', 'Feminino'])
plt.title("Evasões por Gênero\n", fontsize=16)
plt.xlabel('')
plt.ylabel('Quantidade de Clientes\n', fontsize=12)
for i in ax.containers:
    ax.bar_label(
        i,
        fmt='%.1f',    # Formato com 1 decimal
        padding=1,     # Espaçamento
        fontsize=10,
        color='black'
)
plt.legend(title='Evasão', labels=['Não', 'Sim'])
plt.grid(linestyle=':')
sns.despine()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax =sns.countplot(data=dados, x='customer.SeniorCitizen', hue='Churn')
plt.xticks([0, 1], ['idade < 65', 'idade >= 65'])
plt.title("Evasões por idade\n", fontsize=16)
plt.xlabel('')
plt.ylabel('Quantidade de Clientes\n', fontsize=12)
for i in ax.containers:
    ax.bar_label(
        i,
        fmt='%.1f',
        padding=1,
        fontsize=10,
        color='black'
)
plt.legend(title='Evasão', labels=['Não', 'Sim'])
plt.grid(linestyle=':')
sns.despine()
plt.show()

# %%
# Define o tamanho do gráfico
fig, ax = plt.subplots(figsize=(10,5))
# Cria o gráfico de contagem, mas agora separando por 'Churn'
ax = sns.countplot(data=dados, y='NumAddonServices', hue='Churn', palette=('#ED9121','#3457D5'))
plt.yticks([0, 1, 2, 3, 4, 5, 6 ,7 ,8], ['Pelo menos 1 serviço', '+ 1 Serviço adicional','+ 2 Serviços adicionais',
                                         '+3 Serviços adicionais', '+4 Serviços adicionais', '+5 Serviços adicionais', '+6 Serviços adicionais',
                                         '+7 Serviços adicionais', '+8 Serviços adicionais'])

# Adiciona título e labels
ax.set_title('Relação entre Número de Serviços e Evasão\n', fontsize=16)
ax.set_xlabel('Quantidade de Clientes\n', fontsize=12)
ax.set_ylabel('')
for i in ax.containers:
    ax.bar_label(
        i,
        fmt='%.1f',    # Formato com 1 decimal
        padding=1,     # Espaçamento
        fontsize=10,
        color='black'
)

# legenda
plt.legend(title='Evasão', labels=['Sim', 'Não'])
sns.despine()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax =sns.countplot(data=dados, x='internet.InternetService', hue='Churn')
#plt.xticks([0, 1], [])
plt.title("Evasões por tipo de internet\n", fontsize=16)
plt.xlabel('')
plt.ylabel('Quantidade de Clientes\n', fontsize=12)
for i in ax.containers:
    ax.bar_label(
        i,
        fmt='%.1f',    # Formato com 1 decimal
        padding=1,     # Espaçamento
        fontsize=10,
        color='black'
)
plt.legend(title='Evasão', labels=['Não', 'Sim'])
plt.grid(linestyle=':')
sns.despine()

# %%
def tenure_group(tenure):
  if tenure <= 12:
      return 'Novo Cliente (1-12 meses)'
  elif tenure <= 36:
      return 'Cliente Médio (13-36 meses)'
  elif tenure <= 60:
      return 'Cliente Longo (37-60 meses)'
  else:
      return 'Cliente Fiel (61+ meses)'

dados['customer.tenure2'] = dados['customer.tenure'].apply(tenure_group)

fig, ax = plt.subplots(figsize=(10, 5))
# Usamos multiple='dodge' para colocar as barras lado a lado
ax = sns.histplot(data=dados, x='customer.tenure2', hue='Churn', multiple='dodge',
                  shrink=.8)

# Adiciona e formata os títulos e labels
ax.set_title('Contagem de Evasão por Tempo de Contrato', fontsize=16, pad=20)
ax.set_xlabel('Tempo de Contrato', fontsize=12)
ax.set_ylabel('Quantidade de Clientes', fontsize=12)

# Adiciona os rótulos de dados em cima de cada barra
for container in ax.containers:
    ax.bar_label(container, padding=3, fontsize=10)

# Melhora a legenda
plt.legend(title='Evasão', labels=['Não', 'Sim'])
plt.grid(linestyle=':')
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##📄Relatorio Final

# %% [markdown]
# ### **Relatório de Análise Exploratória – Fatores de Evasão de Clientes na TelecomX**
#
#
# #### **1. Introdução: O Problema de Negócio**
#
# A evasão de clientes, ou "Churn", é uma métrica crítica para empresas de serviços recorrentes, como as do setor de telecomunicações. Perder um cliente não representa apenas a perda de receita futura, mas também implica em custos mais elevados para adquirir novos clientes em comparação com os custos de retenção dos existentes.
#
# O presente estudo foi realizado com o objetivo de analisar a base de dados da TelecomX para identificar os principais fatores e padrões de comportamento que estão associados à decisão de um cliente cancelar seus serviços. A compreensão desses fatores é o primeiro passo para desenvolver estratégias de retenção mais eficazes, personalizar ofertas e, consequentemente, aumentar a lucratividade e a sustentabilidade do negócio.
#
# #### **2. Processo de Análise dos Dados**
#
# A análise seguiu um processo estruturado, utilizando o notebook `telecomx_br.py`, que pode ser dividido em três fases principais:
#
# 1.  **Extração e Preparação dos Dados:**
#     * Os dados foram extraídos de um arquivo JSON.
#     * A estrutura aninhada do JSON foi normalizada para um formato de tabela (DataFrame) para facilitar a análise.
#     * Foi realizada uma limpeza nos dados: a coluna de cobrança total (`Charges.Total`) foi convertida de texto para um formato numérico, e valores inconsistentes (espaços em branco) foram tratados como nulos.
#     * Registros que não continham informação sobre a evasão (`Churn`) foram removidos para garantir a precisão da análise.
#
# 2.  **Engenharia de Atributos:**
#     * Para aprofundar a análise, novas colunas (features) foram criadas a partir dos dados existentes:
#         * `account.Charges.Daily`: Calculado dividindo o custo mensal por 30, para obter uma visão do custo diário do serviço.
#         * `NumAddonServices`: Uma contagem do número total de serviços adicionais contratados por cada cliente (ex: segurança online, backup, suporte técnico, etc.).
#         * `customer.tenure2` e `account.Charges.Daily2`: Categorização do tempo de contrato e do custo diário em grupos, facilitando a visualização e interpretação dos gráficos.
#
# 3.  **Análise Exploratória Visual:**
#     * Foram gerados diversos gráficos para visualizar a relação entre as variáveis do cliente (tipo de contrato, tempo de serviço, custo, etc.) e a taxa de evasão. Essa abordagem visual permitiu a rápida identificação de tendências e padrões significativos.
#
# #### **3. Resultados e Descobertas da Análise**
#
# A análise exploratória revelou insights claros sobre o perfil dos clientes que tendem a deixar a empresa.
#
# * **Perfil Geral da Evasão:**
#     * Da base de clientes analisada, **1.869 clientes evadiram**, enquanto **5.174 permaneceram**. Isso representa uma taxa de churn de aproximadamente 26,5% na amostra, um número significativo que justifica a investigação.
#
# * **Tipo de Contrato é o Fator Mais Crítico:**
#     * A análise demonstrou que o tipo de contrato é o indicador mais forte de evasão. Clientes com **contratos mensais** apresentam uma taxa de churn drasticamente maior em comparação com aqueles com contratos de longo prazo (anuais ou bianuais). A flexibilidade do contrato mensal facilita o cancelamento do serviço.
#
# * **Tempo de Contrato (Tenure) e a Lealdade do Cliente:**
#     * Existe uma relação direta entre o tempo de permanência do cliente e sua probabilidade de evasão. **Clientes mais novos (com até 12 meses de contrato) são muito mais propensos a cancelar o serviço**. A taxa de churn diminui consideravelmente à medida que o cliente se torna mais antigo e fiel.
#
# * **Serviços de Internet e Custo Diário:**
#     * Clientes que assinam o serviço de internet via **Fibra Óptica** têm uma taxa de evasão maior do que os assinantes de DSL. Isso pode ser um indicativo de problemas de concorrência, preço ou qualidade percebida nesse serviço específico.
#     * A análise de custo diário mostra que a evasão é mais acentuada em faixas de custo mais altas, especialmente quando combinada com contratos mensais.
#
# * **Influência dos Serviços Adicionais:**
#     * Clientes com um **maior número de serviços adicionais contratados tendem a evadir menos**. Clientes que não evadiram possuem, em média, mais serviços adicionais do que aqueles que evadiram. Isso sugere que quanto mais integrado o cliente está ao ecossistema de serviços da empresa, maior é a sua lealdade.
#
# * **Fatores Demográficos com Menor Impacto:**
#     * **Gênero:** Não foi identificada uma diferença significativa na taxa de evasão entre clientes do sexo masculino e feminino.
#     * **Idade (SeniorCitizen):** Embora clientes idosos (65 anos ou mais) representem uma parcela menor da base total, eles possuem uma taxa de evasão proporcionalmente maior do que os clientes mais jovens.
#
# #### **4. Conclusão e Recomendações Estratégicas**
#
# A análise dos dados da TelecomX permite traçar um perfil claro do cliente com alto risco de evasão: **um cliente recente (baixo tempo de contrato), com contrato do tipo mensal, que possui poucos ou nenhum serviço adicional contratado e, possivelmente, um assinante do serviço de Fibra Óptica.**
#
# Com base nessas descobertas, as seguintes ações estratégicas são recomendadas:
#
# 1.  **Incentivar Contratos de Longo Prazo:** Criar campanhas ativas e oferecer descontos ou benefícios claros para que clientes de contratos mensais migrem para planos anuais ou bianuais.
# 2.  **Foco na Retenção de Novos Clientes:** Desenvolver um programa de "Boas-vindas" e acompanhamento próximo para clientes nos primeiros 12 meses, período em que o risco de churn é maior. Ofertas personalizadas e um suporte técnico proativo podem fazer a diferença.
# 3.  **Promover Pacotes de Serviços (Bundles):** Incentivar a contratação de serviços adicionais, demonstrando o valor agregado e oferecendo descontos na aquisição de pacotes. Isso aumenta a "pegada" do cliente na empresa, tornando a saída mais difícil.
# 4.  **Investigar a Evasão na Fibra Óptica:** Realizar uma análise mais aprofundada sobre os clientes de Fibra Óptica para entender as causas da alta evasão. Pode envolver pesquisa de satisfação, análise da concorrência e revisão da estrutura de preços e qualidade do serviço.
#
# Esta análise exploratória fornece uma base sólida para a tomada de decisões orientada por dados, permitindo que a TelecomX direcione seus esforços de retenção de forma mais eficiente e assertiva.
